# %%
import psutil
import datetime
from datetime import datetime, timedelta 
import time
from pandas import DataFrame
import pandas as pd
import csv
import os
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
data = pd.read_csv('data/data.csv')
data['year'] = '2019'
data['timestamp'] = data['date'].astype(str)+'-'+data['month'].astype(str)+'-'+data['year'].astype(str)+' '+data['hour'].astype(str)+':'+data['min'].astype(str)+':00'

# %%
data.head(30)
# Out:
#     date  month  day  hour  min  disk  cpu_1  cpu_2  cpu_3  cpu_4  year  \
# 0      4      8  Sun    14   27  66.6   40.8   12.2   73.5   10.2  2019
# 1      4      8  Sun    14   57  66.6   17.0    6.1   13.8    5.2  2019
# 2      4      8  Sun    14   59  66.6   52.3    9.9   28.9    6.5  2019
# 3      4      8  Sun    15   29  66.6   18.8    4.9   15.0    3.9  2019
# 4      4      8  Sun    15   59  66.6   17.2    4.0   13.5    3.3  2019
# 5      4      8  Sun    16   29  66.7   20.7    6.1   17.6    5.2  2019
# 6      4      8  Sun    16   59  66.8   44.3   17.8   42.5   16.0  2019
# 7      4      8  Sun    17   29  66.7   28.2    5.4   25.2    4.4  2019
# 8      4      8  Sun    17   59  66.7   32.5    9.2   41.2   10.1  2019
# 9      4      8  Sun    18   29  66.7   10.4    2.8    8.1    2.1  2019
# 10     4      8  Sun    18   59  66.7   12.8    4.4   10.4    3.4  2019
# 11     4      8  Sun    19   29  66.7   13.2    4.7   10.9    4.0  2019
# ...

# %%
data['timestamp'] = pd.to_datetime(data['timestamp'])

# %%
data = pd.DataFrame(data)

# %%
data['time_diff'] = 0
for i in range(data.shape[0] - 1):
    data['time_diff'][i+1] = (data['timestamp'][i+1] - data['timestamp'][i])
# Out:
# /Users/lordvile/anaconda/envs/new/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#     date  month  day  hour  min  disk  cpu_1  cpu_2  cpu_3  cpu_4  year  \
# 0      4      8  Sun    14   27  66.6   40.8   12.2   73.5   10.2  2019
# 1      4      8  Sun    14   57  66.6   17.0    6.1   13.8    5.2  2019
# 2      4      8  Sun    14   59  66.6   52.3    9.9   28.9    6.5  2019
# 3      4      8  Sun    15   29  66.6   18.8    4.9   15.0    3.9  2019
# 4      4      8  Sun    15   59  66.6   17.2    4.0   13.5    3.3  2019
# 5      4      8  Sun    16   29  66.7   20.7    6.1   17.6    5.2  2019
# 6      4      8  Sun    16   59  66.8   44.3   17.8   42.5   16.0  2019
# ...

# %%
for i in range(1,data.shape[0]):
    temp = data['time_diff'][i]
    hours, minutes = temp.seconds//3600, (temp.seconds//60)%60
    if minutes!=30:
        for i in range((hours*60+minutes)%30):
            temp = temp + timedelta(minutes = 30)
            print(temp)
#         break
# Out:
# 2
# 0 days 00:32:00
# 0 days 01:02:00
# 14
# 0 days 02:14:00
# 0 days 02:44:00
# 0 days 03:14:00
# 0 days 03:44:00
# 0 days 04:14:00
# 0 days 04:44:00
# 0 days 05:14:00
# 0 days 05:44:00
# 0 days 06:14:00
# 0 days 06:44:00
# 0 days 07:14:00
# 0 days 07:44:00
# 0 days 08:14:00
# 0 days 08:44:00
# 25
# 0 days 09:55:00
# 0 days 10:25:00
# 0 days 10:55:00
# 0 days 11:25:00
# 0 days 11:55:00
# 0 days 12:25:00
# 0 days 12:55:00
# 0 days 13:25:00
# 0 days 13:55:00
# 0 days 14:25:00
# 0 days 14:55:00
# 0 days 15:25:00
# 0 days 15:55:00
# 0 days 16:25:00
# 0 days 16:55:00
# 0 days 17:25:00
# 0 days 17:55:00
# 0 days 18:25:00
# 0 days 18:55:00
# 0 days 19:25:00
# 0 days 19:55:00
# 0 days 20:25:00
# 0 days 20:55:00
# 0 days 21:25:00
# 0 days 21:55:00
# 23
# 0 days 06:23:00
# 0 days 06:53:00
# 0 days 07:23:00
# 0 days 07:53:00
# 0 days 08:23:00
# 0 days 08:53:00
# 0 days 09:23:00
# 0 days 09:53:00
# 0 days 10:23:00
# 0 days 10:53:00
# 0 days 11:23:00
# 0 days 11:53:00
# 0 days 12:23:00
# ...

# %%
plt.plot(data['timestamp'],data['disk'],label='disk')
